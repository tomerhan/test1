# %% [markdown]
# <a href="https://colab.research.google.com/github/tomerhan/test1/blob/master/ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Mon Mar 23 08:46:00 2026

# %%
print("hello")
# Out:
# hello
